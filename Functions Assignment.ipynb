# %% [markdown]
# 1- What is the difference between a function and a method in Python?
#
# Function: A block of reusable code that performs a specific task and is defined using the def keyword. It can exist independently.
#
# • Method: A function that is associated with an object and is called on that object.
#
# • Methods are essentially functions that belong to objects.
#
# Example:

# %%
def greet(name):
    return f"Hello, {name}"

print(greet("Anand"))  # Function call

name = "Anand"
print(name.upper())   # Method call on string object ``
# Out:
# Hello, Anand
# ANAND

# %% [markdown]
# 2- Explain the concept of function arguments and parameters in Python
#
# • Parameters are the variable names listed in a function definition.
#
# • Arguments are the actual values passed to the function when it is called.
#
#
# Example:

# %%
def add(a, b):  # a and b are parameters
    return a + b

result = add(5, 3)  # 5 and 3 are arguments
print(result)
# Out:
# 8

# %% [markdown]
# 3- What are the different ways to define and call a function in Python?
#
# • Defining:
#
# Using def keyword
#
# Using lambda for anonymous functions
#
# • Calling:
#
# Positional arguments
#
# Keyword arguments
#
# Default arguments
#
# Variable-length arguments (*args, **kwargs)
#
# Example:

# %%
def greet(name="Guest"):
    print(f"Hello, {name}")

greet("Anand")           # Positional
greet(name="Anand")      # Keyword
greet()                   # Default

def show_info(*args, **kwargs):
    print(args)
    print(kwargs)

show_info(1, 2, name="Anand", age=25)

square = lambda x: x * x
print(square(4))          # Lambda function
# Out:
# Hello, Anand
# Hello, Anand
# Hello, Guest
# (1, 2)
# {'name': 'Anand', 'age': 25}
# 16

# %% [markdown]
# 4- What is the purpose of the return statement in a Python function?
#
# • The return statement sends a result back to the caller and ends function execution.
#
# Example:

# %%
def multiply(x, y):
    return x * y

result = multiply(3, 4)
print(result)
# Out:
# 12

# %% [markdown]
# 5- What are iterators in Python and how do they differ from iterables?
#
# • Iterable: An object capable of returning its members one at a time (e.g., list, tuple).
#
# • Iterator: An object that implements the __iter__() and __next__() methods.
#
# Example:

# %%
my_list = [1, 2, 3]         # Iterable
it = iter(my_list)          # Iterator

print(next(it))
print(next(it))
# Out:
# 1
# 2

# %% [markdown]
# 6- Explain the concept of generators in Python and how they are defined
#
# • A generator is a special type of iterator defined using a function with the yield keyword.
#
# • It maintains the function state between calls.
#
# Example:

# %%
def countdown(n):
    while n > 0:
        yield n
        n -= 1

for i in countdown(3):
    print(i)
# Out:
# 3
# 2
# 1

# %% [markdown]
# 7- What are the advantages of using generators over regular functions?
#
# • Memory Efficient: Generates items one at a time.
#
# • Lazy Evaluation: Values are computed only when needed.
#
# • Useful for large data sets or infinite streams.
#
# Example:

# %%
def squares_gen(n):
    for i in range(n):
        yield i * i

for square in squares_gen(5):
    print(square)
# Out:
# 0
# 1
# 4
# 9
# 16

# %% [markdown]
# 8- What is a lambda function in Python and when is it typically used?
#
# • A lambda function is a small anonymous function defined using the lambda keyword.
#
#
# • Used for short, throwaway functions, often in map(), filter(), etc.
#
# Example

# %%
square = lambda x: x * x
print(square(5))

nums = [1, 2, 3]
squares = list(map(lambda x: x * x, nums))
print(squares)
# Out:
# 25
# [1, 4, 9]

# %% [markdown]
# 9- Explain the purpose and usage of the map() function in Python
#
# • map() applies a function to every item of an iterable and returns an iterator.
#
# Example:

# %%
nums = [1, 2, 3, 4]
squared = list(map(lambda x: x**2, nums))
print(squared)
# Out:
# [1, 4, 9, 16]

# %% [markdown]
# 10- What is the difference between map(), reduce(), and filter() functions in Python?
#
#
#
# • map() applies a function to each item in an iterable and returns a map object (which is an iterator).
#
#
# • filter() applies a conditional function to filter items and returns a filter object.
#
#
# • reduce() applies a function cumulatively to the items, reducing the iterable to a single output value.

# %%
from functools import reduce
nums = [1, 2, 3, 4, 5]

# map
squares = list(map(lambda x: x*x, nums))
print(squares)

# filter
evens = list(filter(lambda x: x % 2 == 0, nums))
print(evens)

# reduce
product = reduce(lambda x, y: x * y, nums)
print(product)
# Out:
# [1, 4, 9, 16, 25]
# [2, 4]
# 120

# %% [markdown]
# 11- Using pen & paper, write the internal mechanism for sum operation using reduce() function on the given list: **[47, 11, 42, 13]

# %%
from functools import reduce
nums = [47, 11, 42, 13]
sum_result = reduce(lambda x, y: x + y, nums)

# %%
sum_result
# Out:
# 113

# %% [markdown]
# ![Reduce function .jpg](attachment:e79ec584-efe1-4241-806f-316f34f4490f.jpg)

# %% [markdown]
# 1- Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
# the list.

# %%
def sum_of_even_numbers(n):
    Total = 0
    for number in n:
        if number %2 == 0:
            Total += number
    return Total

# %%
List1 = [1,2,3,4,500,600]
Result = sum_of_even_numbers(List1)
print("The sum of even numbers is: ",Result)
# Out:
# The sum of even numbers is:  1106

# %% [markdown]
# 2- Create a Python function that accepts a string and returns the reverse of that string.

# %%
def reverse_strng(character):
    Reversed_text = ""
    for char in character:
        Reversed_text = char + Reversed_text
    return Reversed_text

# %%
Strng = "Anand"
Result = reverse_strng(Strng)
print("Reversed string is: ",Result)
# Out:
# Reversed string is:  dnanA

# %% [markdown]
# 3- Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number.

# %%
def squares_numbers(n):
    Squares = []
    for i in n:
        Squares.append(i*i)
    return Squares

# %%
List2 = [10,20,30,40,50]
Result = squares_numbers(List2)
print("Squares: ",Result)
# Out:
# Squares:  [100, 400, 900, 1600, 2500]

# %% [markdown]
# 4- Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
def isPrime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return 'No its not a prime number'
    return 'Yes its Prime number'


isPrime(21)
# Out:
# 'No its not a prime number'

# %% [markdown]
# 5- Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
# terms.

# %%
def fib(n):
    a = 0
    b = 1
    for i in range(n):
        yield a
        a,b = b,a+b

# %%
f = fib(100)

# %%
f
# Out:
# <generator object fib at 0x0000023709501A80>

# %%
next(f)
# Out:
# 0

# %%
next(f)
# Out:
# 1

# %%
next(f)
# Out:
# 1

# %%
next(f)
# Out:
# 2

# %%
next(f)
# Out:
# 3

# %%
next(f)
# Out:
# 5

# %%
next(f)
# Out:
# 8

# %%
next(f)
# Out:
# 13

# %% [markdown]
# and so on......

# %% [markdown]
# 6- Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def powers_of_two(max_exponent):
    for i in range(max_exponent + 1):
        yield 2 ** i  # yield 2 raised to the power i

# %%
# Generate powers of 2 up to exponent 5 (i.e., 2^0 to 2^5)
for power in powers_of_two(5):
    print(power)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32

# %% [markdown]
# 7- Implement a generator function that reads a file line by line and yields each line as a string.

# %%
def read_file_line_by_line(filename):
    with open(filename, 'r') as file:
        for line in file:
            yield line.strip()

# %%
for line in read_file_line_by_line('sample3.txt'):
    print(line)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 for line in read_file_line_by_line('sample3.txt'):
#       2     print(line)
#
# Cell In[16], line 2, in read_file_line_by_line(filename)
#       1 def read_file_line_by_line(filename):
# ----> 2     with open(filename, 'r') as file:
#       3         for line in file:
#       4             yield line.strip()
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# ...

# %% [markdown]
# 8- Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
my_list = [(1, 3), (4, 1), (2, 2), (5, 0)]

sorted_list = sorted(my_list, key=lambda x: x[1])

print(sorted_list)
# Out:
# [(5, 0), (4, 1), (2, 2), (1, 3)]

# %% [markdown]
# 9- Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

# %%
celsius_temps = [0, 20, 37, 100]

fahrenheit_temps = list(map(lambda c: (c * 9/5) + 32, celsius_temps))

print("Celsius:", celsius_temps)
print("Fahrenheit:", fahrenheit_temps)
# Out:
# Celsius: [0, 20, 37, 100]
# Fahrenheit: [32.0, 68.0, 98.6, 212.0]

# %% [markdown]
# 10- Create a Python program that uses `filter()` to remove all the vowels from a given string.

# %%
def remove_vowels(text):
    vowels = 'aeiouAEIOU'
    
    result = ''.join(filter(lambda char: char not in vowels, text))
    return result

input_string = "This is Anand Bharadwaj"
output_string = remove_vowels(input_string)

print("Original String:", input_string)
print("Without Vowels: ", output_string)
# Out:
# Original String: This is Anand Bharadwaj
# Without Vowels:  Ths s nnd Bhrdwj

# %% [markdown]
# 11- Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
# ![Screenshot 2025-06-18 173254.png](attachment:5c93885b-a98d-4e1e-a20c-d61b9023179b.png)
#
# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
# product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
# order is smaller than 100,00 €.
#
# Write a Python program using lambda and map

# %%
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einfuhrung in Python3, Bernd Klein", 3, 24.99]
]


order_totals = list(map(lambda order:
    (order[0], order[2] * order[3] + 10 if order[2] * order[3] < 100 else order[2] * order[3]), orders))

print(order_totals)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
